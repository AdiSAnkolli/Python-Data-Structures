# %%
class Node:
    def __init__(self, val):
        self.left = None
        self.right = None
        self.v = val

class Tree:
    def __init__(self):
        self.root = None
        
    def GetRoot(self):
        return self.root
    
    def add(self, val):
        if (self.root is None):
            self.root = Node(val)
        else:
            self._add(val, self.root)
            
    def _add(self, val, node):
        if (val < node.v):
            if (node.left is not None):
                self._add(val, node.left)
            else:
                node.left = Node(val)
        else:
            if (node.right is not None):
                self._add(val, node.right)
            else:
                node.right = Node(val)
    
    def find(self, val):
        if (self.root is not None):
            return self._find(val, self.root)
        
    def _find(self, val, node):
        if (val == node.v):
            print("\nFound the value\n")
        elif (val < node.v and node.left is not None):
            self._find(val, node,left)
        elif (val > node.v and node.right is not None):
            self._find(val, node.right)
        else:
            print("\nValue not found\n")
                  
    def deleteTree(self):
                  self.root = None
                  print("\n\n Tree Deleted \n\n")
    
    def printTree(self):
        if (self.root is not None):
            print(" Printing the tree values \n")
            self._printTree(self.root)
    
    def _printTree(self, node):
        if (node is not None):
                        self._printTree(node.left)
                        print("", str(node.v), "")
                        self._printTree(node.right)
                        
                        
tree = Tree() # Initializing object of class tree
while True:
    print("1) Add elements\n2) Search for elements\n3) Print Tree\n4) Delete Tree and exit")
    choice = int(input("Enter your choice :  "))
    if (choice == 1):
        val = int(input("Enter the value to be inserted in Tree\n"))
        tree.add(val)
    elif (choice == 2):
        val = int(input("Enter the value to be searched\n"))
        tree.find(val)
    elif (choice == 3):
        tree.printTree()
    elif (choice == 4):
        tree.deleteTree()
        break
    else:
        print("Please enter correct value")
# Out:
# 1) Add elements
# 2) Search for elements
# 3) Print Tree
# 4) Delete Tree and exit
# Enter your choice :  1
# Enter the value to be inserted in Tree
# 1
# 1) Add elements
# 2) Search for elements
# 3) Print Tree
# 4) Delete Tree and exit
# Enter your choice :  1
# Enter the value to be inserted in Tree
# 2
# 1) Add elements
# 2) Search for elements
# 3) Print Tree
# 4) Delete Tree and exit
# Enter your choice :  2
# Enter the value to be searched
# 3
#
# Value not found
#
# 1) Add elements
# 2) Search for elements
# 3) Print Tree
# 4) Delete Tree and exit
# Enter your choice :  2
# Enter the value to be searched
# 2
#
# Found the value
#
# 1) Add elements
# 2) Search for elements
# 3) Print Tree
# 4) Delete Tree and exit
# Enter your choice :  3
#  Printing the tree values
#
#  1
#  2
# 1) Add elements
# 2) Search for elements
# 3) Print Tree
# 4) Delete Tree and exit
# Enter your choice :  4
#
#
#  Tree Deleted
